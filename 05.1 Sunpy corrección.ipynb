# %% [markdown]
# <div style="background-color:#ffe6f0; padding:18px; border-radius:12px; border:1px solid #ffb3d1; color:#1a1a1a;">
#
# 🌸 <span style="color:#c2185b; font-size:22px;"><b>Sunpy corrección</b></span>
#
# <p style="color:black;">
# Profe, le adjunto el link del Colab para que pueda verificar el código y todo lo que realicé.
# Intenté subir el archivo a GitHub por diferentes métodos, pero no me fue posible lograrlo correctamente.
#
#
# https://colab.research.google.com/drive/1V7dDu6_ZP9VFocBEYrTycL7iyXePJL2D
#
# <p style="color:black;">
# Sin embargo, adjuntaré los resultados obtenidos a partir de la implementación del código, junto con las gráficas correspondientes para su respectivo análisis.
#
# 🌸 <span style="font-size:18px; font-weight:bold; color:#c2185b">Pregunta 5 — Solar Physics Integration (SunPy)</span>
#
# <br>
#
# **a) Pico ~15–17 min: ¿qué modo es?**
# El periodograma (Lomb-Scargle) muestra un pico dominante en **~16.69 min**, cercano al valor esperado de ~15 min.
# Esto es consistente con una **oscilación magnetoacústica de periodo largo** en la región activa, y no con los **p-modes globales (5 min)** del Sol.
#
# <br>
#
# **b) ¿Por qué usar submap y no promedio de disco completo?**
# Se utiliza un **submap** porque la señal es **local de la región activa**.
# El promedio del disco completo mezcla regiones tranquilas con variaciones globales, lo que **reduce el contraste** y puede **distorsionar el período dominante**.
#
# <br>
#
# **c) Ajuste seno amortiguado vs modelo tipo box (χ²)**
#
# El ajuste con un seno amortiguado describe mejor la variación observada:
#
# - χ²<sub>seno amortiguado</sub> = **91.00**
# - χ²<sub>box</sub> = **377.36**
#
# Dado que el χ² del seno amortiguado es significativamente menor (≈4 veces), este modelo representa mejor los datos y confirma un comportamiento **oscilatorio amortiguado**.
#
# 🌸 <span style="color:#c2185b; font-size:22px;"><b>Región activa solar (ROI) en AIA 171 Å</b></span>
#
#  ![Región activa.png](attachment:4e046b5f-651a-47de-a3be-2239fad3e94a.png)
#
#  Se identifica y aísla una región activa del Sol utilizando observaciones en 171 Å, permitiendo analizar estructuras coronales y su variabilidad local mediante un recorte espacial (ROI).
#
#  ---
#
#  🌸 <span style="color:#c2185b; font-size:22px;"><b>Curva de luz de la región activa (submap AR) con suavizado</b></span>
#  ![curva suave.png](attachment:598ecd3c-5766-4d58-86a1-74e69909f8f8.png)
#
# Se construyó la curva de luz de la región activa a partir de la serie temporal de intensidades, convirtiendo el tiempo a minutos desde el inicio de la observación. Posteriormente, se aplicó un filtro de Savitzky–Golay (ventana 9, orden 2) con el fin de suavizar la señal y resaltar su comportamiento global. Finalmente, se graficaron tanto los datos originales como la tendencia suavizada, permitiendo identificar variaciones y posibles oscilaciones en la emisión.
#
# ---
#  🌸 <span style="color:#c2185b; font-size:22px;"><b>Periodograma Lomb–Scargle de la región activa (ROI óptima)</b></span>
#  ![pico 15 min.png](attachment:7776c8d7-b0e8-44ab-9c71-1f6990ffbd9a.png)
#
# Se calcula el periodograma Lomb–Scargle sobre la señal detrendida de múltiples regiones candidatas, seleccionando aquella cuya oscilación dominante se aproxima a ~15 min. El pico principal (16.7 min) evidencia una periodicidad característica de la región activa, consistente con oscilaciones locales de origen magnetoacústico.
#
# ---
#  🌸 <span style="color:#c2185b; font-size:22px;"><b>Comparación de ajustes en la curva de luz (seno amortiguado vs. modelo caja)</b></span>
#  ![comparacion de ajustes .png](attachment:edce00f2-f21d-4182-8f1c-98ce3c983cd2.png)
#
# Probé dos formas de modelar la señal: un seno amortiguado (más físico) y un modelo tipo caja (más simplificado). Al comparar con χ² y la forma de la curva, se ve que el seno amortiguado sigue mucho mejor la variación real, mientras que el modelo caja se queda corto porque no captura la continuidad de la señal.
#
#
#
# </p>
#
# </div>
