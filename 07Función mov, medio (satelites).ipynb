# %% [markdown]
# <div style="background-color:#ffe6f0; padding:18px; border-radius:12px; border:1px solid #ffb3d1; color:#1a1a1a;">
#
# 🌸 <span style="color:#c2185b; font-size:22px;"><b>Movimiento medio en órbitas</b></span>
#
# ---
#
# No es una “función cualquiera”. Es la <b>velocidad angular promedio</b> de un objeto en órbita:
#
# $$
# n = \sqrt{\frac{\mu}{a^3}}
# $$
#
# ---
# • $n$: movimiento medio (qué tan rápido orbita)
# • $\mu$: parámetro gravitacional
# • $a$: semieje mayor de la órbita
#
# ---
#
# Para aplicar métodos numéricos como:
#
# • Riemann
# • Trapecio
# • Trapecio compuesto
# • Simpson 1/3
#
# Necesitamos definir un intervalo en $a$ y un valor de $\mu$. Trabajaré en unidades estándar de astrodinámica (km):
#
# $$
# \mu = 398600 \, \text{km}^3/\text{s}^2
# $$
#
# $$
# a \in [7000, 8000] \, \text{km}
# $$
#
# ---
# Valor “real” (Para comparar errores)
#
# $$
# \int_{7000}^{8000} \frac{\mu}{a^3} \, da
# =
# \int_{7000}^{8000} \mu \, a^{-3/2} \, da
# $$
#
# $$
# = \mu \left[ -2 a^{-1/2} \right]_{7000}^{8000}
# $$
#
# $$
# = 2\mu \left( \frac{1}{7000} - \frac{1}{8000} \right)
# $$
#
# Numéricamente:
#
# $$
# I \approx 0.974733
# $$
#
# ---
# Elegimos:
#
# $$
# n = 4
# $$
#
# (subintervalos, porque Simpson 1/3 exige $n$ par)
#
# $$
# h = \frac{b - a}{n} = \frac{8000 - 7000}{4} = 250
# $$
#
# Nodos:
#
# $$
# a_0 = 7000, \quad
# a_1 = 7250, \quad
# a_2 = 7500, \quad
# a_3 = 7750, \quad
# a_4 = 8000
# $$
#
# Valores (aprox):
#
# $$
# f(a_0) = 0.001078007
# $$
#
# $$
# f(a_1) = 0.001022732
# $$
#
# $$
# f(a_2) = 0.000972088
# $$
#
# $$
# f(a_3) = 0.000925678
# $$
#
# $$
# f(a_4) = 0.000882335
# $$
#
# ---
#
# **1) Suma de Riemann**
#
# $$
# R = h \sum_{i=1}^{4} f(a_i)
# $$
#
# $$
# R \approx 0.950615
# $$
#
# ---
#
# **2) Regla del Trapecio (simple)**
#
# $$
# T = \frac{b - a}{2} \left[ f(a) + f(b) \right]
# $$
#
# $$
# T \approx 0.980171
# $$
#
# ---
#
# **3) Trapecio compuesto (n = 4)**
#
# $$
# T_c = \frac{h}{2} \left[ f(a_0) + 2 \sum_{i=1}^{3} f(a_i) + f(a_4) \right]
# $$
#
# $$
# T_c \approx 0.975074
# $$
#
# ---
#
# **4) Simpson 1/3 (n = 4)**
#
# $$
# S = \frac{h}{3} \left[ f(a_0) + 4f(a_1) + 2f(a_2) + 4f(a_3) + f(a_4) \right]
# $$
#
# $$
# S \approx 0.974733
# $$
#
# </div>
