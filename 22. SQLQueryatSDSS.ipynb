# %% [markdown]
# <div style="
# background-color:#ffe6f0;
# padding:24px;
# border-radius:16px;
# border:1.5px solid #ffb3d1;
# color:#1a1a1a;
# font-size:16px;
# line-height:1.8;
# ">
#
# <h2 style="
# margin-top:0;
# color:#c2185b;
# font-size:28px;
# ">
# SQLQueryatSDSS.ipynb
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# background-color:#ffe6f0;
# padding:24px;
# border-radius:16px;
# border:1.5px solid #ffb3d1;
# color:#1a1a1a;
# font-size:16px;
# line-height:1.8;
# ">
#
# <h3 style="
# margin-top:0;
# color:#c2185b;
# font-size:26px;
# ">
# Preguntas
# </h3>
#
# <p>
# <b>1.</b> Modifica la consulta anterior para que devuelva los valores <code>ra</code> y <code>dec</code> de los objetos donde <code>ra</code> esté entre 140,25 y 140,75 y <code>dec</code> entre 20,25 y 20,75. ¿Cuántos objetos devolvió la consulta? ¿Tiene sentido esto, considerando el área de búsqueda más pequeña?
# </p>
#
# <p>
# <b>2.</b> Modifique su consulta para que devuelva la ascensión recta (<code>ra</code>), la declinación (<code>dec</code>) y el mejor ID de objeto para galaxias, y solo galaxias, cuya <code>ra</code> esté entre 140,25 y 140,75 y cuya declinación esté entre 20,25 y 20,75.
# </p>
#
# </div>

# %% [markdown]
# ![SQL1](sql1.jpeg)

# %% [markdown]
# ![SQL1](sql2.jpeg)

# %% [markdown]
# <div style="
# background-color:#ffe6f0;
# padding:24px;
# border-radius:16px;
# border:1.5px solid #ffb3d1;
# color:#1a1a1a;
# font-size:16px;
# line-height:1.8;
# ">
#
# <h3 style="
# margin-top:0;
# color:#c2185b;
# font-size:26px;
# ">
# Preguntas
# </h3>
#
# <p>
# <b>3.</b> Galaxias más rojas en la región del cielo cercana a <code>ra = 141</code>. Escriba una consulta para buscar galaxias entre <code>ra = 140.9</code> y <code>ra = 141.1</code> más brillantes que <code>g = 18.0</code> para las cuales el índice de color (<code>u-g</code>) satisface <code>u - g &gt; 2.2</code>. Recupere el ID del objeto, <code>ra</code>, <code>dec</code> y las cinco magnitudes finales.
# </p>
#
# <p>
# <b>4.</b> Cuásares con mayor corrimiento al rojo en la base de datos SDSS. Escribe una consulta para buscar cuásares para los que hayamos obtenido espectros (tabla <code>specObj</code>) con corrimientos al rojo mayores de <code>4.5</code> y buenas mediciones (<code>zWarning = 0</code>). Recupera el ID de foto, ascensión recta, declinación y corrimiento al rojo de cada cuásar. ¿Cuál es el cuásar con el mayor valor de <code>z</code>?
# </p>
#
# </div>

# %% [markdown]
# ![SQL1](sql3.jpeg)

# %% [markdown]
# <div style="
# background-color:#ffe6f0;
# padding:22px;
# border-radius:16px;
# border:1.5px solid #ffb3d1;
# color:#1a1a1a;
# font-size:16px;
# line-height:1.8;
# ">
#
# <h3 style="
# margin-top:0;
# color:#c2185b;
# font-size:26px;
# ">
# Respuesta
# </h3>
#
# <p>
# En esta consulta busqué galaxias cercanas a <code>ra = 141</code>, restringiendo la región entre <code>140.9</code> y <code>141.1</code>.
# </p>
#
# <p>
# Además, seleccioné únicamente objetos brillantes con <code>g &lt; 18.0</code> y galaxias rojas utilizando el criterio de color <code>u - g &gt; 2.2</code>.
# </p>
#
# <p>
# Se recuperaron el ID del objeto, sus coordenadas <code>ra</code> y <code>dec</code>, junto con las cinco magnitudes fotométricas <code>u</code>, <code>g</code>, <code>r</code>, <code>i</code> y <code>z</code>.
# </p>
#
# </div>

# %% [markdown]
# ![SQL1](sql4.jpeg)

# %% [markdown]
# <div style="
# background-color:#ffe6f0;
# padding:22px;
# border-radius:16px;
# border:1.5px solid #ffb3d1;
# color:#1a1a1a;
# font-size:16px;
# line-height:1.8;
# ">
#
# <h3 style="
# margin-top:0;
# color:#c2185b;
# font-size:26px;
# ">
# Respuesta
# </h3>
#
# <p>
# La consulta permitió identificar cuásares con corrimientos al rojo mayores que <code>4.5</code> y mediciones confiables (<code>zWarning = 0</code>). Los resultados fueron ordenados de forma descendente según el valor de <code>z</code>.
# </p>
#
# <p>
# El cuásar con el mayor corrimiento al rojo encontrado en la base de datos SDSS tiene:
# </p>
#
# <ul>
# <li><b>bestObjID</b> = 1237668591340290733</li>
# <li><b>ra</b> = 200.99695°</li>
# <li><b>dec</b> = 17.910995°</li>
# <li><b>z</b> = 7.042325</li>
# </ul>
#
# <p>
# Este objeto corresponde al cuásar más distante encontrado por la consulta, ya que presenta el mayor valor de corrimiento al rojo de toda la muestra recuperada.
# </p>
#
# </div>
