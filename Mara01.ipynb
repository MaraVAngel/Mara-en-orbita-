# %%
print("Hola Marita en órbita 💫")
# Out:
# Hola Marita en órbita 💫

# %%
print("Marita en órbita conectada 🚀")
# Out:
# Marita en órbita conectada 🚀

# %%
git add .
git commit -m "Primer notebook Mara01"
git push
# Out:
#   Cell In[2], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
